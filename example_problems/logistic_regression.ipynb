# %%
import sys
sys.path.append('/Users/vikaspandey/my_projects/deeplearning_ai')
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from algorithms.regression.logistic_regression import LogisticRegressor
from data_visualisation.bar_chart.bar import Bar

# %%
data = pd.read_csv('../datasets/classification_data.csv', sep=',', names=['exam1_marks', 'exam2_marks', 'result'])
data.keys()
# Out:
# Index(['exam1_marks', 'exam2_marks', 'result'], dtype='object')

# %%
bar = Bar((15,10))
bar.x_coords = np.arange(10)
bar.bar_heights = data['exam1_marks'][:10]
bar.title = 'Marks of students in exam1'
bar.xlabel = "Marks"
bar.xlabel_attrs = {'fontsize': 20}
bar.show(show_percentage=True)
# Out:
# /Users/vikaspandey/miniconda2/envs/datascience/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# /Users/vikaspandey/miniconda2/envs/datascience/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# /Users/vikaspandey/miniconda2/envs/datascience/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# /Users/vikaspandey/miniconda2/envs/datascience/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# ...

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
admitted = data.loc[y == 1]
not_admitted = data.loc[y == 0]

# %%
plt.scatter(admitted.iloc[:, 0], admitted.iloc[:, 1], s=10, label='Admitted')
plt.scatter(not_admitted.iloc[:, 0], not_admitted.iloc[:, 1], s=10, label='Not Admitted')
plt.show()
# Out:
# /Users/vikaspandey/miniconda2/envs/datascience/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
X = np.c_[np.ones((X.shape[0], 1)), X]
y = y[:, np.newaxis]
theta = np.zeros((X.shape[1], 1))

# %%
l = LogisticRegressor()
l.fit(X, y)

# %%
parameters = l.w

# %%
x_values = [np.min(X[:, 1] - 5), np.max(X[:, 2] + 5)]
y_values = - (parameters[0] + np.dot(parameters[1], x_values)) / parameters[2]

plt.plot(x_values, y_values, label='Decision Boundary')
plt.xlabel('Marks in 1st Exam')
plt.ylabel('Marks in 2nd Exam')
plt.legend()
plt.show()

# %%
l.accuracy(X, y)
# Out:
# 52.4640342822161
